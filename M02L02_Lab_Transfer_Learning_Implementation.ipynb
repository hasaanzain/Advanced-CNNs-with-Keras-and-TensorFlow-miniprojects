# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Lab: Transfer Learning Implementation

# %% [markdown]
# ##### Estimated time needed:  30 minutes

# %% [markdown]
# In this lab, you will learn to implement transfer learning using a pre-trained model in Keras.
#
# #### Learning objectives
#
# By the end of this lab, you will:
#
#  - Import necessary libraries and load the dataset.
#  - Load a pre-trained model, VGG16, excluding the top layers.
#  - Add new layers on top of the base model and compile the model.
#  - Train the model on the new dataset.
#  - Unfreeze some of the layers of the pre-trained model and fine-tune them.

# %% [markdown]
# ### Step-by-Step Guide:
#
# #### Step 1: Setup the Environment
#
# Before we start, make sure to import the required libraries: TensorFlow and Keras. Keras is included within TensorFlow as `tensorflow.keras`.

# %%
# !pip install tensorflow==2.16.2 matplotlib==3.9.1
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Collecting tensorflow==2.16.2
#   Downloading tensorflow-2.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting matplotlib==3.9.1
#   Downloading matplotlib-3.9.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.16.2)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.16.2)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow==2.16.2)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow==2.16.2)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.16.2)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow==2.16.2)
#   Downloading h5py-3.16.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.2)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.16.2)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2)
#   Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.16.2)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow==2.16.2)
#   Downloading wrapt-2.1.2-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.16.2)
#   Downloading grpcio-1.80.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow==2.16.2)
#   Downloading keras-3.14.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow==2.16.2)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.9.1)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib==3.9.1)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.9.1)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.9.1)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pillow>=8 (from matplotlib==3.9.1)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.9.1)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2) (0.45.1)
# Collecting rich (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading optree-0.19.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2024.12.14)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.0.0->tensorflow==2.16.2)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# WARNING: The candidate selected for download or install is a yanked version: 'matplotlib' candidate (version 3.9.1 at https://files.pythonhosted.org/packages/0d/cb/78283ec2ded91fb74a2ae9ae93f91a897fa578fa78c8c271a7c147f6b8d6/matplotlib-3.9.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/matplotlib/) (requires-python:>=3.9))
# Reason for being yanked: The Windows wheels, under some conditions, caused segfaults in unrelated user code.  Due to this we deleted the Windows wheels to prevent these segfaults, however this caused greater disruption as pip then began to try (and fail) to build 3.9.1 from the sdist on Windows which impacted far more users.  Yanking the whole release is the only tool available to eliminate these failures without changes to on the user side.  The sdist, OSX wheel, and manylinux wheels are all functional and there are no critical bugs in the release.   Downstream packagers should not yank their builds of Matplotlib 3.9.1.  See https://github.com/matplotlib/matplotlib/issues/28551 for details.
# Downloading tensorflow-2.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (590.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.8/590.8 MB 1.3 MB/s eta 0:00:00:00:0100:01
# Downloading matplotlib-3.9.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 1.6 MB/s eta 0:00:000:00:01
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 29.7 MB/s eta 0:00:00
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.80.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 48.5 MB/s eta 0:00:00
# Downloading h5py-3.16.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 28.5 MB/s eta 0:00:00
# Downloading keras-3.14.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.7 MB/s eta 0:00:00eta 0:00:01
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 45.0 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 47.8 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 36.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 33.5 MB/s eta 0:00:00:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 52.3 MB/s eta 0:00:00
# Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl (295 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 22.4 MB/s eta 0:00:00ta 0:00:01
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (121 kB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 59.2 MB/s eta 0:00:00
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (457 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, pyparsing, protobuf, pillow, optree, opt-einsum, numpy, mdurl, markdown, kiwisolver, grpcio, google-pasta, gast, fonttools, cycler, astunparse, absl-py, tensorboard, ml-dtypes, markdown-it-py, h5py, contourpy, rich, matplotlib, keras, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.63.0 gast-0.7.0 google-pasta-0.2.0 grpcio-1.80.0 h5py-3.16.0 keras-3.14.1 kiwisolver-1.5.0 libclang-18.1.1 markdown-3.10.2 markdown-it-py-4.2.0 matplotlib-3.9.1 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.1.0 numpy-1.26.4 opt-einsum-3.4.0 optree-0.19.1 pillow-12.2.0 protobuf-4.25.9 pyparsing-3.3.2 rich-15.0.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 termcolor-3.3.0 werkzeug-3.1.8 wrapt-2.1.2
# 2026-05-19 15:02:29.967273: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-19 15:02:29.968809: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-19 15:02:29.973912: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-19 15:02:29.987709: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-19 15:02:30.014885: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-19 15:02:30.014968: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-19 15:02:30.035244: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-19 15:02:31.222266: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ##### Explanation:
# - `tensorflow` is the main library for machine learning in Python.
# - `Sequential` is used to create a model with a linear stack of layers.
# - `Dense` and `Flatten` are types of layers that we will use in our model.

# %% [markdown]
# #### Step 2: Load Pre-trained Model

# %%
# Load the VGG16 model pre-trained on ImageNet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# #### Step 3: Create and Compile the Model

# %%
# Create a new model and add the base model and new layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')  # Change to the number of classes you have
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### **Create Placeholder Images**

# %%
import os
from PIL import Image
import numpy as np

# Create directories if they don't exist
os.makedirs('sample_data/class_a', exist_ok=True)
os.makedirs('sample_data/class_b', exist_ok=True)

# Create 10 sample images for each class
for i in range(10):
    # Create a blank white image for class_a
    img = Image.fromarray(np.ones((224, 224, 3), dtype=np.uint8) * 255)
    img.save(f'sample_data/class_a/img_{i}.jpg')

    # Create a blank black image for class_b
    img = Image.fromarray(np.zeros((224, 224, 3), dtype=np.uint8))
    img.save(f'sample_data/class_b/img_{i}.jpg')

print("Sample images created in 'sample_data/'")
# Out:
# Sample images created in 'sample_data/'

# %% [markdown]
# #### Step 4: Train the Model

# %%
# Load and preprocess the dataset
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Verify if the generator has loaded images correctly
print(f"Found {train_generator.samples} images belonging to {train_generator.num_classes} classes.")

# Train the model
if train_generator.samples > 0:
    model.fit(train_generator, epochs=10)
# Out:
# Found 20 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.6983
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 6.0559
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.5000 - loss: 2.7945
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 0.5577
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.5000 - loss: 0.8939
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.5000 - loss: 0.9282
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 0.9021
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.5000 - loss: 0.8417
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 0.7686
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 0.6960

# %% [markdown]
# #### Step 5: Fine-Tune the Model

# %%
# Unfreeze the top layers of the base model 

for layer in base_model.layers[-4:]:
    layer.trainable = True 

# Compile the model again 
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) 

# Train the model again 
model.fit(train_generator, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.6360
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 4.9679
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 7.9151
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.7897
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 1.0199
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.7941
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.6913
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.6735
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.6609
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6246

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Exercise 1: Visualize Training and Validation Loss
#
# **Objective:** Plot the training and validation loss to observe the learning process of the model.
#
# **Instructions:**
# 1. Modify the training code to include validation data.
# 2. Plot the training and validation loss for each epoch.

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Train the model with validation data
history = model.fit(train_generator, epochs=10, validation_data=validation_generator)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Found 16 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.9548 - val_accuracy: 0.5000 - val_loss: 0.7241
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.7241 - val_accuracy: 0.5000 - val_loss: 0.6615
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6615 - val_accuracy: 0.5000 - val_loss: 0.6332
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.6332 - val_accuracy: 0.5000 - val_loss: 0.6299
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.6299 - val_accuracy: 1.0000 - val_loss: 0.5394
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 1.0000 - loss: 0.5394 - val_accuracy: 1.0000 - val_loss: 0.4803
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.4803 - val_accuracy: 0.5000 - val_loss: 0.4883
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.4883 - val_accuracy: 1.0000 - val_loss: 0.3064
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.3064 - val_accuracy: 1.0000 - val_loss: 0.2180
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.2180 - val_accuracy: 1.0000 - val_loss: 0.1539

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# # Modify data generator to include validation data
# train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
#
# train_generator = train_datagen.flow_from_directory(
#     'sample_data',
#     target_size=(224, 224),
#     batch_size=32,
#     class_mode='binary',
#     subset='training'
# )
#
# validation_generator = train_datagen.flow_from_directory(
#     'sample_data',
#     target_size=(224, 224),
#     batch_size=32,
#     class_mode='binary',
#     subset='validation'
# )
#
# # Train the model with validation data
# history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# # Plot training and validation loss
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %% [markdown]
# #### Exercise 2: Experiment with Different Optimizers
#
# **Objective:** Experiment with different optimizers and observe their impact on model performance.
#
# **Instructions:**
# 1. Change the optimizer from `adam` to `sgd` and `rmsprop`.
# 2. Retrain the model with each optimizer and compare the accuracy.

# %%
from tensorflow.keras.models import clone_model
import matplotlib.pyplot as plt

# Function to reset the model weights
def reset_model(model):
    # Clone the model to reset weights
    model_clone = clone_model(model)
    model_clone.set_weights(model.get_weights())
    return model_clone

# Prepare to reset the model for each optimizer test
initial_model = reset_model(model)  # Assume 'model' is the initial compiled model

# Experiment with SGD optimizer
sgd_model = reset_model(initial_model)  # Reset model
sgd_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
history_sgd = sgd_model.fit(train_generator, epochs=10, validation_data=validation_generator)

# Plot training and validation accuracy for SGD
plt.plot(history_sgd.history['accuracy'], label='Training Accuracy SGD')
plt.plot(history_sgd.history['val_accuracy'], label='Validation Accuracy SGD')
plt.title('Training and Validation Accuracy with SGD')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Experiment with RMSprop optimizer
rmsprop_model = reset_model(initial_model)  # Reset model
rmsprop_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
history_rmsprop = rmsprop_model.fit(train_generator, epochs=10, validation_data=validation_generator)

# Plot training and validation accuracy for RMSprop
plt.plot(history_rmsprop.history['accuracy'], label='Training Accuracy RMSprop')
plt.plot(history_rmsprop.history['val_accuracy'], label='Validation Accuracy RMSprop')
plt.title('Training and Validation Accuracy with RMSprop')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 1.0000 - loss: 0.1539 - val_accuracy: 0.5000 - val_loss: 5.5785
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 5.5785 - val_accuracy: 0.5000 - val_loss: 0.6473
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6473 - val_accuracy: 0.5000 - val_loss: 0.6269
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6269 - val_accuracy: 0.5000 - val_loss: 1.0551
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 1.0551 - val_accuracy: 1.0000 - val_loss: 0.6897
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.6897 - val_accuracy: 0.5000 - val_loss: 0.6878
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6878 - val_accuracy: 0.5000 - val_loss: 0.6861
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6861 - val_accuracy: 0.5000 - val_loss: 0.6844
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 0.6844 - val_accuracy: 0.5000 - val_loss: 0.6827
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6827 - val_accuracy: 0.5000 - val_loss: 0.6809
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 1.0000 - loss: 0.1539 - val_accuracy: 0.5000 - val_loss: 23.2129
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 23.2129 - val_accuracy: 0.5000 - val_loss: 0.8048
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.8048 - val_accuracy: 0.5000 - val_loss: 0.7105
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.7105 - val_accuracy: 0.5000 - val_loss: 1.1426
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 1.1426 - val_accuracy: 0.5000 - val_loss: 0.7892
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.7892 - val_accuracy: 1.0000 - val_loss: 0.6468
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.6468 - val_accuracy: 0.5000 - val_loss: 2.5577
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 2.5577 - val_accuracy: 0.5000 - val_loss: 0.7043
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.7043 - val_accuracy: 1.0000 - val_loss: 0.6135
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.6135 - val_accuracy: 0.5000 - val_loss: 0.5649

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# from tensorflow.keras.models import clone_model
# import matplotlib.pyplot as plt
#
# # Function to reset the model weights
# def reset_model(model):
#     # Clone the model to reset weights
#     model_clone = clone_model(model)
#     model_clone.set_weights(model.get_weights())
#     return model_clone
#
# # Prepare to reset the model for each optimizer test
# initial_model = reset_model(model)  # Assume 'model' is the initial compiled model
#
# # Experiment with SGD optimizer
# sgd_model = reset_model(initial_model)  # Reset model
# sgd_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
# history_sgd = sgd_model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# # Plot training and validation accuracy for SGD
# plt.plot(history_sgd.history['accuracy'], label='Training Accuracy SGD')
# plt.plot(history_sgd.history['val_accuracy'], label='Validation Accuracy SGD')
# plt.title('Training and Validation Accuracy with SGD')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()
#
# # Experiment with RMSprop optimizer
# rmsprop_model = reset_model(initial_model)  # Reset model
# rmsprop_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
# history_rmsprop = rmsprop_model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# # Plot training and validation accuracy for RMSprop
# plt.plot(history_rmsprop.history['accuracy'], label='Training Accuracy RMSprop')
# plt.plot(history_rmsprop.history['val_accuracy'], label='Validation Accuracy RMSprop')
# plt.title('Training and Validation Accuracy with RMSprop')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %% [markdown]
# #### Exercise 3: Evaluate the Model on a Test Set
#
# **Objective:** Evaluate the fine-tuned model on an unseen test set to assess its generalization performance.
#
# **Instructions:**
# 1. Load a separate test set.
# 2. Evaluate the model on this test set and report the accuracy and loss.

# %%
# Load and preprocess the test dataset
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Evaluate the fine-tuned model on the test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Found 20 images belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 1.0000 - loss: 0.1539
# Test Accuracy: 100.00%
# Test Loss: 0.1539

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# # Load and preprocess the test dataset
# test_datagen = ImageDataGenerator(rescale=1./255)
# test_generator = test_datagen.flow_from_directory(
#     'sample_data',
#     target_size=(224, 224),
#     batch_size=32,
#     class_mode='binary'
# )
#
# # Evaluate the fine-tuned model on the test set
# test_loss, test_accuracy = model.evaluate(test_generator)
# print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# print(f'Test Loss: {test_loss:.4f}')

# %% [markdown]
# ### Summary
#
# By completing these exercises, students will:
#
# 1. Visualize the training and validation loss to gain insights into the training process.
# 2. Experiment with different optimizers to understand their impact on model performance.
# 3. Evaluate the fine-tuned model on an unseen test set to assess its generalization capability.

# %% [markdown]
# #### Conclusion
#
# Congratulations! In this lab, you have successfully implemented transfer learning using a pre-trained model in Keras. This lab exercise demonstrated how to train and fine-tune the model by unfreezing some of the layers.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
